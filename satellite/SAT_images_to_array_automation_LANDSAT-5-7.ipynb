# %% [markdown]
# ### CAPTURE SATELLITE IMAGES FOR PAST PERIOD WITH LANDSAT-5 (1984 - 2000)

# %%
import ee
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import time
from datetime import date
import json
from json import JSONEncoder

# %% [markdown]
# Authentification auprès de Google Engine :
#
# Cliquer sur le lien et suivre les instructions (avec compte google connecté) pour récupérer le token à copier-coller.

# %%
#ee.Authenticate()
ee.Initialize()
print(ee.Image("NASA/NASADEM_HGT/001").get("title").getInfo())
# Out:
# NASADEM: NASA NASADEM Digital Elevation 30m

# %% [markdown]
# -----------

# %% [markdown]
# IMPORT AND MANAGE DATA :

# %%
data = pd.read_excel('DataFrames/data_parcelles_with_gps.xlsx')

# %%
data_used = data[['PARCELLE','LAT', 'LON','DATE','LFI']]

# %% [markdown]
# Filtrage de campagne :

# %%
LFI = 'LFI3'

data_used = data_used.loc[data_used['LFI']==LFI,:]

# %% [markdown]
# Code for a test on few lines :

# %%
#data_used = data_used[0:5]

# %% [markdown]
# Code for a problematic relaunch (to filter the dataset with the problematic parcelles list) :

# %%
#pb_list_df = pd.read_csv('Problematic_parcelles.csv')
#pb_list = pb_list_df['Problematic parcelles'].to_list()
#data_used = data_used.loc[data_used['PARCELLE'].isin(pb_list),:]

# %% [markdown]
# --------------------------

# %% [markdown]
# CLASS FOR EXCEPTIONS :

# %%
class NoImage(Exception):
    def __init__(self, nb_image):
        self.__nb_image = nb_image

    @property
    def nb_image(self):
        return self.__nb_image

# %%
class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, (datetime, date)):
            return str(obj)
        return json.JSONEncoder.default(self, obj)

# %% [markdown]
# FUNCTIONS (FOR LANDSAT-5 & 7):

# %%
def NDVI(img): #repère la végétation tout simplement
    img = ee.Image(img.normalizedDifference(['B4', 'B3'])).rename(["ndvi"])
    return img

def EVI(img): #idem NDVI, plus fiable et fin en théorie
    img = ee.Image(img.expression(
        '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))', {
            'NIR': img.select('B4').divide(10000),
            'RED': img.select('B3').divide(10000),
            'BLUE': img.select('B1').divide(10000)
        })).rename(["evi"])
    
    return img

def NDMI(img): #repère la teneur en eau dans la végétation
    #img = ee.Image(img.normalizedDifference(['B8', 'B11'])).rename(["ndmi"])
    img = ee.Image(img.expression(
        '(NIR - SWITCH) / (SWITCH + NIR)', {
            'NIR': img.select('B4').divide(10000),
            'SWITCH': img.select('B5').divide(10000)
       })).rename(["ndmi"])
    return img

def NDWI(img): #teneur en d'eau en surface
    #img = ee.Image(img.normalizedDifference(['B3', 'B8'])).rename(["ndwi"])
    img = ee.Image(img.expression(
        '(GREEN - NIR) / (GREEN + NIR)', {
            'NIR': img.select('B4').divide(10000),
            'GREEN': img.select('B2').divide(10000)
        })).rename(["ndwi"])
    return img


def DSWI(img): # Disease Water Stress Index sensitive to stress due to water shortage and plant damage
    img = ee.Image(img.expression(
        '(NIR - GREEN) / (SWIR1 + RED)', {
            'NIR': img.select('B4').divide(10000),
            'RED': img.select('B3').divide(10000),
            'GREEN': img.select('B2').divide(10000),
            'SWIR1': img.select('B5').divide(10000),
        })).rename(["dswi"])
    
    return img

def B1(img):
    b2 = ee.Image(img.select(['B1'])).divide(10000).rename(["b1"])
    return b2

def B2(img):
    b2 = ee.Image(img.select(['B2'])).divide(10000).rename(["b2"])
    return b2

def B3(img):
    b3 = ee.Image(img.select(['B3'])).divide(10000).rename(["b3"])
    print('add b3')
    return b3

def B4(img):
    b4 = ee.Image(img.select(['B4'])).divide(10000).rename(["b4"])
    return b4

def B5(img):
    b5 = ee.Image(img.select(['B5'])).divide(10000).rename(["b5"])
    return b5

# %%
def collection_to_array(lat_loc, lon_loc, date_dep, date_fin):
    global dim_image, percentage_max_cloud_cover, Spectral_Band_init, Spectral_Functions, Sattelite
    pas_lat = dim_image/111120
    pas_lon = dim_image/111120

    area = ee.Geometry.BBox(lon_loc - pas_lon/2, lat_loc-pas_lat/2, lon_loc + pas_lon/2, lat_loc + pas_lat/2)
    pas_lon_cos = dim_image/(111120 * np.cos(lat_loc*np.pi/180))
    area_cos = ee.Geometry.BBox(lon_loc - pas_lon_cos/2, lat_loc-pas_lat/2, lon_loc + pas_lon_cos/2, lat_loc + pas_lat/2)

    collection = ee.ImageCollection(Sattelite).filterBounds(area_cos) \
                                      .filterDate(date_dep,date_fin) \
                                      #.filterMetadata("CLOUDY_PIXEL_PERCENTAGE","less_than",percentage_max_cloud_cover)\
                                      #.select(Spectral_Band_init) \
                                      
                                      
    print('collection')
    nb_images = collection.size().getInfo()
    print(f'{nb_images} images founded...')

    if nb_images == 0:
        raise NoImage(nb_images)

    im_dict = dict()

    
    for _, funct in enumerate(Spectral_Functions):
        myCollection  = collection.map(Spectral_Functions.get(funct))
        img = ee.Image(myCollection.mean()).rename(['result'])
        img = img.addBands(ee.Image.pixelLonLat())
        img = img.reduceRegion(reducer=ee.Reducer.toList(),\
                                        geometry=area,\
                                        maxPixels=1e8,\
                                        scale=1)
        data = np.array((ee.Array(img.get('result')).getInfo()))
        lats = np.array((ee.Array(img.get("latitude")).getInfo()))
        lons = np.array((ee.Array(img.get("longitude")).getInfo()))
        uniqueLats = np.unique(lats)
        uniqueLons = np.unique(lons)
        ncols = len(uniqueLons)
        nrows = len(uniqueLats)
        arr = np.zeros([nrows, ncols], np.float32)
        counter =0
        for y in range(0,len(arr),1):
            for x in range(0,len(arr[0]),1):
                if lats[counter] == uniqueLats[y] and lons[counter] == uniqueLons[x] and counter < len(lats)-1:
                    counter+=1
                    arr[len(uniqueLats)-1-y,x] = data[counter]

        im_dict[f'{funct}'] = arr

        if funct==NDVI:
            im_dict[f'TNDVI'] = np.sqrt(arr) + 0.5
    
    return im_dict

# %% [markdown]
# --------------

# %% [markdown]
# USER'S PARAMETERS :

# %%
Sattelite = 'LANDSAT/LT05/C02/T1'

dim_image = 200 #mètres de côté

# %% [markdown]
# OTHERS PARAMETERS

# %% [markdown]
# Paramètre de pourcentage de couverture nuageuse (filtre) :

# %%
#percentage_max_cloud_cover = 100

# %% [markdown]
# Besoins en bandes spectrales (pour les fonctions) :

# %%
#Spectral_Band_init = ['B2', 'B3', 'B4', 'B5']

# %% [markdown]
# Important : garder le format dictionnaire

# %%
Spectral_Functions = {'NDVI':NDVI, 'EVI':EVI, 'NDMI':NDMI, 'NDWI':NDWI, 'DSWI':DSWI}

# %% [markdown]
# Moitié d'ouverture temporelle (centrée au 30 juin) :

# %%
days = 15

# %% [markdown]
# La collection d'images se fera entre date - days et date + days...

# %% [markdown]
# ------------

# %% [markdown]
# IMAGES CAPTURE :

# %%
data_lfi = data_used.loc[data_used['LFI']==LFI,:]
data_lfi['YEAR'] = data_lfi['DATE'].map(lambda d : d.year)
if LFI=='LFI1':
    data_lfi['YEAR'] = data_lfi['YEAR'].map(lambda d: 1984 if d==1983 else d)
print (f"For campaign {LFI}, all the images will be extracted for this years : {data_lfi['YEAR'].unique()}...")

# --- FORCE TEST YEAR --- 
#data_lfi['YEAR'] = 1990

#data_lfi = data_lfi[0:5]

# --- END TEST ---

nb_lines = len(data_lfi)
matrix_data = np.matrix(data_lfi)

Stock_images_list =dict()
Problem_list = []

for i in range(nb_lines):
    deb_image = time.time()
    parc_name = matrix_data.item(i, 0)
    print(f'--- PARCELLE {matrix_data.item(i, 0)} ---')
    parc_dict=dict()
    date_image = datetime.datetime.strptime(str(matrix_data.item(i, 5)) + '-06-30', '%Y-%m-%d')
    date_dep = (date_image - datetime.timedelta(days=days))
    date_fin = (date_image + datetime.timedelta(days=days))
    date_dep_string = str(date_dep.year) + '-' + str(date_dep.month) + '-' + str(date_dep.day)
    date_fin_string = str(date_fin.year) + '-' + str(date_fin.month) + '-' + str(date_fin.day)
    lat_loc = matrix_data.item(i, 1)
    lon_loc = matrix_data.item(i, 2)

    try:
        dict_images = collection_to_array(lat_loc, lon_loc, date_dep, date_fin)
    except NoImage:
        date_dep -= datetime.timedelta(days=days)
        date_fin += datetime.timedelta(days=days)
        print(f'Zéro images for parcelle {parc_name}... so we tried with a days open of {days*4} days...')
        try:
            dict_images = collection_to_array(lat_loc, lon_loc, date_dep, date_fin)
        except NoImage:
            date_dep -= datetime.timedelta(days=days)
            date_fin += datetime.timedelta(days=days)
            print(f'Zéro images for parcelle {parc_name}... so we tried with a days open of {days*8} days...')
            try:
                dict_images = collection_to_array(lat_loc, lon_loc, date_dep, date_fin)
            except:
                print(f'--- PROBLEM ! with parcelle {parc_name}... ---')
                dict_images = np.nan
                Problem_list.append(parc_name)
        except:
            print(f'--- PROBLEM ! with parcelle {parc_name}... ---')
            dict_images = np.nan
            Problem_list.append(parc_name)
    except:
        print(f'--- PROBLEM ! with parcelle {parc_name}... ---')
        dict_images = np.nan
        Problem_list.append(parc_name)


    parc_dict['PARCELLE'] = matrix_data.item(i, 0)
    parc_dict['LAT, LON'] = (lat_loc, lon_loc)
    parc_dict['DATE_INIT'] = str(matrix_data.item(i, 3))
    parc_dict['LFI'] = matrix_data.item(i, 4)
    parc_dict['DATE_IMAGE_SAT'] = str(date_image)
    parc_dict['IMAGES_SAT'] = dict_images
    Stock_images_list[f'{matrix_data.item(i, 0)}'] = parc_dict
    fin_image = time.time()
    print(f'This image traitment took {round(fin_image - deb_image,4)} seconds... ')

print('Finish !...')
print(f'But we have a problem with this list of parcelles : {Problem_list}')
# Out:
# For campaign LFI3, all the images will be extracted for this years : [2005 2004 2006]...
# --- PARCELLE 51 ---
# collection
# 2 images founded...
# This image traitment took 18.0753 seconds...
# --- PARCELLE 384 ---
# collection
# 2 images founded...
# This image traitment took 19.3199 seconds...
# --- PARCELLE 1239 ---
# collection
# 4 images founded...
# This image traitment took 23.6332 seconds...
# --- PARCELLE 1419 ---
# collection
# 4 images founded...
# This image traitment took 17.9004 seconds...
# --- PARCELLE 1431 ---
# collection
# 4 images founded...
# This image traitment took 21.0489 seconds...
# --- PARCELLE 1636 ---
# collection
# 4 images founded...
# This image traitment took 26.7181 seconds...
# --- PARCELLE 1823 ---
# collection
# 4 images founded...
# This image traitment took 21.6836 seconds...
# --- PARCELLE 3848 ---
# collection
# 4 images founded...
# This image traitment took 15.7045 seconds...
# --- PARCELLE 4161 ---
# collection
# 2 images founded...
# This image traitment took 17.2515 seconds...
# --- PARCELLE 4694 ---
# collection
# 4 images founded...
# This image traitment took 18.8156 seconds...
# --- PARCELLE 5124 ---
# collection
# 2 images founded...
# This image traitment took 22.2752 seconds...
# --- PARCELLE 6128 ---
# collection
# 2 images founded...
# This image traitment took 15.8486 seconds...
# --- PARCELLE 6767 ---
# collection
# 2 images founded...
# This image traitment took 14.2891 seconds...
# --- PARCELLE 7355 ---
# collection
# 2 images founded...
# This image traitment took 17.1336 seconds...
# --- PARCELLE 7383 ---
# collection
# 3 images founded...
# This image traitment took 19.288 seconds...
# --- PARCELLE 7395 ---
# collection
# 4 images founded...
# This image traitment took 20.6284 seconds...
# --- PARCELLE 8122 ---
# collection
# 4 images founded...
# This image traitment took 16.6807 seconds...
# --- PARCELLE 8146 ---
# collection
# 4 images founded...
# This image traitment took 17.1897 seconds...
# --- PARCELLE 8804 ---
# collection
# 1 images founded...
# This image traitment took 16.1219 seconds...
# --- PARCELLE 9231 ---
# collection
# 2 images founded...
# This image traitment took 15.7715 seconds...
# --- PARCELLE 9395 ---
# collection
# 4 images founded...
# This image traitment took 16.9432 seconds...
# --- PARCELLE 9423 ---
# collection
# 2 images founded...
# This image traitment took 26.0114 seconds...
# --- PARCELLE 9871 ---
# collection
# 3 images founded...
# This image traitment took 35.9085 seconds...
# --- PARCELLE 9943 ---
# collection
# 4 images founded...
# This image traitment took 16.1735 seconds...
# --- PARCELLE 10802 ---
# collection
# 2 images founded...
# This image traitment took 22.7096 seconds...
# --- PARCELLE 10814 ---
# collection
# 2 images founded...
# This image traitment took 15.4645 seconds...
# --- PARCELLE 10834 ---
# collection
# 1 images founded...
# This image traitment took 13.5996 seconds...
# --- PARCELLE 10842 ---
# collection
# 1 images founded...
# This image traitment took 27.7958 seconds...
# --- PARCELLE 10846 ---
# collection
# 1 images founded...
# This image traitment took 11.903 seconds...
# --- PARCELLE 11547 ---
# collection
# 1 images founded...
# This image traitment took 15.2919 seconds...
# --- PARCELLE 11555 ---
# collection
# 1 images founded...
# This image traitment took 16.0997 seconds...
# --- PARCELLE 12230 ---
# collection
# 2 images founded...
# This image traitment took 16.6553 seconds...
# --- PARCELLE 12234 ---
# collection
# 2 images founded...
# This image traitment took 23.6845 seconds...
# --- PARCELLE 12258 ---
# collection
# 1 images founded...
# This image traitment took 15.8553 seconds...
# --- PARCELLE 12262 ---
# collection
# 1 images founded...
# This image traitment took 20.7293 seconds...
# --- PARCELLE 12286 ---
# collection
# 1 images founded...
# This image traitment took 14.5144 seconds...
# --- PARCELLE 12290 ---
# collection
# 1 images founded...
# This image traitment took 25.493 seconds...
# --- PARCELLE 12298 ---
# collection
# 2 images founded...
# This image traitment took 25.5093 seconds...
# --- PARCELLE 12762 ---
# collection
# 2 images founded...
# This image traitment took 20.5289 seconds...
# --- PARCELLE 13014 ---
# collection
# 1 images founded...
# This image traitment took 21.5329 seconds...
# --- PARCELLE 13440 ---
# collection
# 3 images founded...
# This image traitment took 16.4835 seconds...
# --- PARCELLE 13508 ---
# collection
# 2 images founded...
# This image traitment took 18.6866 seconds...
# --- PARCELLE 13676 ---
# collection
# 2 images founded...
# This image traitment took 20.2676 seconds...
# --- PARCELLE 13720 ---
# collection
# 1 images founded...
# This image traitment took 11.6726 seconds...
# --- PARCELLE 13732 ---
# collection
# 1 images founded...
# This image traitment took 19.7873 seconds...
# --- PARCELLE 14229 ---
# collection
# 3 images founded...
# This image traitment took 26.1207 seconds...
# --- PARCELLE 14233 ---
# collection
# 3 images founded...
# This image traitment took 16.2876 seconds...
# --- PARCELLE 14241 ---
# collection
# 2 images founded...
# This image traitment took 16.3139 seconds...
# --- PARCELLE 14477 ---
# collection
# 1 images founded...
# This image traitment took 15.1979 seconds...
# --- PARCELLE 14493 ---
# collection
# 1 images founded...
# This image traitment took 16.7411 seconds...
# --- PARCELLE 14955 ---
# collection
# 3 images founded...
# This image traitment took 15.328 seconds...
# --- PARCELLE 14983 ---
# collection
# 3 images founded...
# This image traitment took 14.5627 seconds...
# --- PARCELLE 15015 ---
# collection
# 3 images founded...
# This image traitment took 16.7155 seconds...
# --- PARCELLE 15055 ---
# collection
# 2 images founded...
# This image traitment took 17.7628 seconds...
# --- PARCELLE 15215 ---
# collection
# 2 images founded...
# This image traitment took 17.9615 seconds...
# --- PARCELLE 15299 ---
# collection
# 1 images founded...
# This image traitment took 17.6421 seconds...
# --- PARCELLE 15780 ---
# collection
# 3 images founded...
# This image traitment took 15.361 seconds...
# --- PARCELLE 15884 ---
# collection
# 2 images founded...
# This image traitment took 21.8876 seconds...
# --- PARCELLE 16028 ---
# collection
# 4 images founded...
# This image traitment took 16.1893 seconds...
# --- PARCELLE 16060 ---
# collection
# 2 images founded...
# This image traitment took 14.9601 seconds...
# --- PARCELLE 16076 ---
# collection
# 2 images founded...
# This image traitment took 11.7707 seconds...
# --- PARCELLE 16096 ---
# collection
# 1 images founded...
# This image traitment took 25.1631 seconds...
# --- PARCELLE 16570 ---
# collection
# 3 images founded...
# This image traitment took 15.1961 seconds...
# --- PARCELLE 16610 ---
# collection
# 3 images founded...
# This image traitment took 13.9872 seconds...
# --- PARCELLE 16694 ---
# collection
# 2 images founded...
# This image traitment took 12.5177 seconds...
# --- PARCELLE 16850 ---
# collection
# 4 images founded...
# This image traitment took 15.2735 seconds...
# --- PARCELLE 16854 ---
# collection
# 4 images founded...
# This image traitment took 14.9245 seconds...
# --- PARCELLE 16866 ---
# collection
# 2 images founded...
# This image traitment took 16.731 seconds...
# --- PARCELLE 16870 ---
# collection
# 2 images founded...
# This image traitment took 12.6458 seconds...
# --- PARCELLE 16878 ---
# collection
# 2 images founded...
# This image traitment took 24.4404 seconds...
# --- PARCELLE 17421 ---
# collection
# 3 images founded...
# This image traitment took 16.8713 seconds...
# --- PARCELLE 17437 ---
# collection
# 3 images founded...
# This image traitment took 10.9675 seconds...
# --- PARCELLE 17441 ---
# collection
# 3 images founded...
# This image traitment took 17.9031 seconds...
# --- PARCELLE 17501 ---
# collection
# 3 images founded...
# This image traitment took 15.0934 seconds...
# --- PARCELLE 17673 ---
# collection
# 2 images founded...
# This image traitment took 13.1989 seconds...
# --- PARCELLE 17705 ---
# collection
# 2 images founded...
# This image traitment took 10.8143 seconds...
# --- PARCELLE 17745 ---
# collection
# 1 images founded...
# This image traitment took 21.8977 seconds...
# --- PARCELLE 17757 ---
# collection
# 1 images founded...
# This image traitment took 25.6436 seconds...
# --- PARCELLE 17765 ---
# collection
# 1 images founded...
# This image traitment took 8.9746 seconds...
# --- PARCELLE 18244 ---
# collection
# 3 images founded...
# This image traitment took 20.9968 seconds...
# --- PARCELLE 18256 ---
# collection
# 3 images founded...
# This image traitment took 19.6731 seconds...
# --- PARCELLE 18260 ---
# collection
# 3 images founded...
# This image traitment took 15.4976 seconds...
# --- PARCELLE 18284 ---
# collection
# 3 images founded...
# This image traitment took 24.1807 seconds...
# --- PARCELLE 18288 ---
# collection
# 3 images founded...
# This image traitment took 22.4294 seconds...
# --- PARCELLE 18292 ---
# collection
# 3 images founded...
# This image traitment took 19.5169 seconds...
# --- PARCELLE 18344 ---
# collection
# 3 images founded...
# This image traitment took 15.959 seconds...
# --- PARCELLE 18364 ---
# collection
# 2 images founded...
# This image traitment took 16.7772 seconds...
# --- PARCELLE 18516 ---
# collection
# 4 images founded...
# This image traitment took 16.207 seconds...
# --- PARCELLE 18520 ---
# collection
# 2 images founded...
# This image traitment took 13.5935 seconds...
# --- PARCELLE 18560 ---
# collection
# 2 images founded...
# This image traitment took 21.3855 seconds...
# --- PARCELLE 18600 ---
# collection
# 1 images founded...
# This image traitment took 18.7326 seconds...
# --- PARCELLE 19059 ---
# collection
# 3 images founded...
# This image traitment took 17.4478 seconds...
# --- PARCELLE 19063 ---
# collection
# 3 images founded...
# This image traitment took 14.451 seconds...
# --- PARCELLE 19067 ---
# collection
# 3 images founded...
# This image traitment took 15.2168 seconds...
# --- PARCELLE 19071 ---
# collection
# 3 images founded...
# This image traitment took 16.2449 seconds...
# --- PARCELLE 19099 ---
# collection
# 3 images founded...
# This image traitment took 14.5748 seconds...
# --- PARCELLE 19159 ---
# collection
# 3 images founded...
# This image traitment took 12.1698 seconds...
# --- PARCELLE 19335 ---
# collection
# 2 images founded...
# This image traitment took 12.3464 seconds...
# --- PARCELLE 19347 ---
# collection
# 2 images founded...
# This image traitment took 22.5265 seconds...
# --- PARCELLE 19885 ---
# collection
# 3 images founded...
# This image traitment took 16.7033 seconds...
# --- PARCELLE 19893 ---
# collection
# 3 images founded...
# This image traitment took 16.4837 seconds...
# --- PARCELLE 19905 ---
# collection
# 3 images founded...
# This image traitment took 24.3586 seconds...
# --- PARCELLE 19909 ---
# collection
# 3 images founded...
# This image traitment took 16.0271 seconds...
# --- PARCELLE 19913 ---
# collection
# 3 images founded...
# This image traitment took 19.1525 seconds...
# --- PARCELLE 19941 ---
# collection
# 3 images founded...
# This image traitment took 15.8995 seconds...
# --- PARCELLE 19945 ---
# collection
# 3 images founded...
# This image traitment took 16.4365 seconds...
# --- PARCELLE 19973 ---
# collection
# 3 images founded...
# This image traitment took 16.2557 seconds...
# --- PARCELLE 19985 ---
# collection
# 3 images founded...
# This image traitment took 23.6381 seconds...
# --- PARCELLE 19993 ---
# collection
# 3 images founded...
# This image traitment took 16.7932 seconds...
# --- PARCELLE 20005 ---
# collection
# 2 images founded...
# This image traitment took 14.7776 seconds...
# --- PARCELLE 20213 ---
# collection
# 2 images founded...
# This image traitment took 23.9799 seconds...
# --- PARCELLE 20217 ---
# collection
# 2 images founded...
# This image traitment took 15.5615 seconds...
# --- PARCELLE 20233 ---
# collection
# 1 images founded...
# This image traitment took 14.1965 seconds...
# --- PARCELLE 20253 ---
# collection
# 1 images founded...
# This image traitment took 13.0506 seconds...
# --- PARCELLE 20696 ---
# collection
# 3 images founded...
# This image traitment took 14.1784 seconds...
# --- PARCELLE 20700 ---
# collection
# 3 images founded...
# This image traitment took 15.2099 seconds...
# --- PARCELLE 20704 ---
# collection
# 3 images founded...
# This image traitment took 12.0489 seconds...
# --- PARCELLE 20712 ---
# collection
# 3 images founded...
# This image traitment took 13.4856 seconds...
# --- PARCELLE 20720 ---
# collection
# 3 images founded...
# This image traitment took 13.408 seconds...
# --- PARCELLE 20780 ---
# collection
# 3 images founded...
# This image traitment took 12.5011 seconds...
# --- PARCELLE 20812 ---
# collection
# 3 images founded...
# This image traitment took 14.1782 seconds...
# --- PARCELLE 20980 ---
# collection
# 2 images founded...
# This image traitment took 12.3087 seconds...
# --- PARCELLE 20988 ---
# collection
# 2 images founded...
# This image traitment took 19.8769 seconds...
# --- PARCELLE 21024 ---
# collection
# 2 images founded...
# This image traitment took 16.6549 seconds...
# --- PARCELLE 21064 ---
# collection
# 1 images founded...
# This image traitment took 25.3222 seconds...
# --- PARCELLE 21491 ---
# collection
# 3 images founded...
# This image traitment took 13.4867 seconds...
# --- PARCELLE 21495 ---
# collection
# 3 images founded...
# This image traitment took 11.5225 seconds...
# --- PARCELLE 21499 ---
# collection
# 3 images founded...
# This image traitment took 16.1004 seconds...
# --- PARCELLE 21551 ---
# collection
# 3 images founded...
# This image traitment took 17.1557 seconds...
# --- PARCELLE 21587 ---
# collection
# 3 images founded...
# This image traitment took 9.7783 seconds...
# --- PARCELLE 21767 ---
# collection
# 2 images founded...
# This image traitment took 12.131 seconds...
# --- PARCELLE 21771 ---
# collection
# 2 images founded...
# This image traitment took 9.0667 seconds...
# --- PARCELLE 21823 ---
# collection
# 1 images founded...
# This image traitment took 11.834 seconds...
# --- PARCELLE 22248 ---
# collection
# 3 images founded...
# This image traitment took 25.95 seconds...
# --- PARCELLE 22260 ---
# collection
# 3 images founded...
# This image traitment took 8.786 seconds...
# --- PARCELLE 22540 ---
# collection
# 2 images founded...
# This image traitment took 13.1648 seconds...
# --- PARCELLE 22556 ---
# collection
# 2 images founded...
# This image traitment took 24.0073 seconds...
# --- PARCELLE 23029 ---
# collection
# 3 images founded...
# This image traitment took 23.8734 seconds...
# --- PARCELLE 23085 ---
# collection
# 3 images founded...
# This image traitment took 15.9052 seconds...
# --- PARCELLE 23089 ---
# collection
# 3 images founded...
# This image traitment took 16.0973 seconds...
# --- PARCELLE 23321 ---
# collection
# 2 images founded...
# This image traitment took 17.6938 seconds...
# --- PARCELLE 23325 ---
# collection
# 2 images founded...
# This image traitment took 15.9415 seconds...
# --- PARCELLE 23361 ---
# collection
# 1 images founded...
# This image traitment took 16.857 seconds...
# --- PARCELLE 23381 ---
# collection
# 1 images founded...
# This image traitment took 14.9463 seconds...
# --- PARCELLE 23792 ---
# collection
# 3 images founded...
# This image traitment took 16.2289 seconds...
# --- PARCELLE 23832 ---
# collection
# 3 images founded...
# This image traitment took 15.8677 seconds...
# --- PARCELLE 23840 ---
# collection
# 3 images founded...
# This image traitment took 22.1521 seconds...
# --- PARCELLE 23848 ---
# collection
# 3 images founded...
# This image traitment took 25.4381 seconds...
# --- PARCELLE 24088 ---
# collection
# 2 images founded...
# This image traitment took 15.0729 seconds...
# --- PARCELLE 24148 ---
# collection
# 1 images founded...
# This image traitment took 14.7983 seconds...
# --- PARCELLE 24152 ---
# collection
# 1 images founded...
# This image traitment took 19.8216 seconds...
# --- PARCELLE 24156 ---
# collection
# 1 images founded...
# This image traitment took 11.3469 seconds...
# --- PARCELLE 24560 ---
# collection
# 3 images founded...
# This image traitment took 14.9886 seconds...
# --- PARCELLE 24572 ---
# collection
# 3 images founded...
# This image traitment took 13.2317 seconds...
# --- PARCELLE 24604 ---
# collection
# 3 images founded...
# This image traitment took 14.9901 seconds...
# --- PARCELLE 24624 ---
# collection
# 3 images founded...
# This image traitment took 14.4383 seconds...
# --- PARCELLE 24628 ---
# collection
# 3 images founded...
# This image traitment took 11.4654 seconds...
# --- PARCELLE 24680 ---
# collection
# 2 images founded...
# This image traitment took 12.5409 seconds...
# --- PARCELLE 24848 ---
# collection
# 2 images founded...
# This image traitment took 14.7074 seconds...
# --- PARCELLE 24852 ---
# collection
# 2 images founded...
# This image traitment took 12.8947 seconds...
# --- PARCELLE 24876 ---
# collection
# 2 images founded...
# This image traitment took 13.3873 seconds...
# --- PARCELLE 24900 ---
# collection
# 1 images founded...
# This image traitment took 13.9216 seconds...
# --- PARCELLE 24916 ---
# collection
# 1 images founded...
# This image traitment took 12.9914 seconds...
# --- PARCELLE 25319 ---
# collection
# 3 images founded...
# This image traitment took 11.8667 seconds...
# --- PARCELLE 25335 ---
# collection
# 3 images founded...
# This image traitment took 14.7682 seconds...
# --- PARCELLE 25347 ---
# collection
# 3 images founded...
# This image traitment took 18.3884 seconds...
# --- PARCELLE 25351 ---
# collection
# 3 images founded...
# This image traitment took 18.2929 seconds...
# --- PARCELLE 25359 ---
# collection
# 3 images founded...
# This image traitment took 18.9134 seconds...
# --- PARCELLE 25363 ---
# collection
# 3 images founded...
# This image traitment took 14.6405 seconds...
# --- PARCELLE 25367 ---
# collection
# 3 images founded...
# This image traitment took 14.8167 seconds...
# --- PARCELLE 25371 ---
# collection
# 3 images founded...
# This image traitment took 15.0661 seconds...
# --- PARCELLE 25379 ---
# collection
# 3 images founded...
# This image traitment took 13.7586 seconds...
# --- PARCELLE 25383 ---
# collection
# 3 images founded...
# This image traitment took 11.896 seconds...
# --- PARCELLE 25387 ---
# collection
# 3 images founded...
# This image traitment took 12.3567 seconds...
# --- PARCELLE 25611 ---
# collection
# 2 images founded...
# This image traitment took 11.8285 seconds...
# --- PARCELLE 25619 ---
# collection
# 2 images founded...
# This image traitment took 23.9563 seconds...
# --- PARCELLE 25623 ---
# collection
# 2 images founded...
# This image traitment took 16.257 seconds...
# --- PARCELLE 25643 ---
# collection
# 2 images founded...
# This image traitment took 16.4454 seconds...
# --- PARCELLE 25667 ---
# collection
# 1 images founded...
# This image traitment took 16.3916 seconds...
# --- PARCELLE 25675 ---
# collection
# 1 images founded...
# This image traitment took 15.9928 seconds...
# --- PARCELLE 26094 ---
# collection
# 3 images founded...
# This image traitment took 18.145 seconds...
# --- PARCELLE 26102 ---
# collection
# 3 images founded...
# This image traitment took 16.4181 seconds...
# --- PARCELLE 26134 ---
# collection
# 3 images founded...
# This image traitment took 18.5696 seconds...
# --- PARCELLE 26146 ---
# collection
# 3 images founded...
# This image traitment took 16.2395 seconds...
# --- PARCELLE 26158 ---
# collection
# 3 images founded...
# This image traitment took 15.9417 seconds...
# --- PARCELLE 26162 ---
# collection
# 3 images founded...
# This image traitment took 16.0787 seconds...
# --- PARCELLE 26382 ---
# collection
# 2 images founded...
# This image traitment took 18.633 seconds...
# --- PARCELLE 26394 ---
# collection
# 2 images founded...
# This image traitment took 14.2799 seconds...
# --- PARCELLE 26402 ---
# collection
# 2 images founded...
# This image traitment took 16.5089 seconds...
# --- PARCELLE 26418 ---
# collection
# 2 images founded...
# This image traitment took 16.3503 seconds...
# --- PARCELLE 26426 ---
# collection
# 2 images founded...
# This image traitment took 11.3476 seconds...
# --- PARCELLE 26430 ---
# collection
# 2 images founded...
# This image traitment took 11.7104 seconds...
# --- PARCELLE 26438 ---
# collection
# 1 images founded...
# This image traitment took 11.4338 seconds...
# --- PARCELLE 26442 ---
# collection
# 1 images founded...
# This image traitment took 18.32 seconds...
# --- PARCELLE 26450 ---
# collection
# 1 images founded...
# This image traitment took 19.1789 seconds...
# --- PARCELLE 26454 ---
# collection
# 1 images founded...
# This image traitment took 27.032 seconds...
# --- PARCELLE 26462 ---
# collection
# 1 images founded...
# This image traitment took 13.2 seconds...
# --- PARCELLE 26890 ---
# collection
# 3 images founded...
# This image traitment took 13.4172 seconds...
# --- PARCELLE 26894 ---
# collection
# 3 images founded...
# This image traitment took 13.7917 seconds...
# --- PARCELLE 26906 ---
# collection
# 3 images founded...
# This image traitment took 13.0476 seconds...
# --- PARCELLE 26918 ---
# collection
# 3 images founded...
# This image traitment took 12.194 seconds...
# --- PARCELLE 26930 ---
# collection
# 3 images founded...
# This image traitment took 13.5858 seconds...
# --- PARCELLE 26938 ---
# collection
# 3 images founded...
# This image traitment took 16.4258 seconds...
# --- PARCELLE 27170 ---
# collection
# 2 images founded...
# This image traitment took 14.5909 seconds...
# --- PARCELLE 27238 ---
# collection
# 1 images founded...
# This image traitment took 14.0958 seconds...
# --- PARCELLE 27676 ---
# collection
# 3 images founded...
# This image traitment took 16.8813 seconds...
# --- PARCELLE 27680 ---
# collection
# 3 images founded...
# This image traitment took 16.5858 seconds...
# --- PARCELLE 27704 ---
# collection
# 3 images founded...
# This image traitment took 16.5599 seconds...
# --- PARCELLE 27748 ---
# collection
# 3 images founded...
# This image traitment took 20.1878 seconds...
# --- PARCELLE 27940 ---
# collection
# 2 images founded...
# This image traitment took 12.2757 seconds...
# --- PARCELLE 28020 ---
# collection
# 1 images founded...
# This image traitment took 21.4785 seconds...
# --- PARCELLE 28496 ---
# collection
# 3 images founded...
# This image traitment took 14.0739 seconds...
# --- PARCELLE 28512 ---
# collection
# 3 images founded...
# This image traitment took 21.6674 seconds...
# --- PARCELLE 28524 ---
# collection
# 3 images founded...
# This image traitment took 15.6623 seconds...
# --- PARCELLE 28616 ---
# collection
# 4 images founded...
# This image traitment took 33.0502 seconds...
# --- PARCELLE 28744 ---
# collection
# 2 images founded...
# This image traitment took 21.5923 seconds...
# --- PARCELLE 28756 ---
# collection
# 2 images founded...
# This image traitment took 15.3883 seconds...
# --- PARCELLE 28772 ---
# collection
# 2 images founded...
# This image traitment took 16.3668 seconds...
# --- PARCELLE 29201 ---
# collection
# 3 images founded...
# This image traitment took 23.7462 seconds...
# --- PARCELLE 29297 ---
# collection
# 3 images founded...
# This image traitment took 15.0105 seconds...
# --- PARCELLE 29525 ---
# collection
# 2 images founded...
# This image traitment took 16.42 seconds...
# --- PARCELLE 30038 ---
# collection
# 3 images founded...
# This image traitment took 16.2234 seconds...
# --- PARCELLE 30078 ---
# collection
# 3 images founded...
# This image traitment took 22.0453 seconds...
# --- PARCELLE 30218 ---
# collection
# 2 images founded...
# This image traitment took 18.8347 seconds...
# --- PARCELLE 30290 ---
# collection
# 2 images founded...
# This image traitment took 14.682 seconds...
# --- PARCELLE 30322 ---
# collection
# 2 images founded...
# This image traitment took 12.4339 seconds...
# --- PARCELLE 30354 ---
# collection
# 1 images founded...
# This image traitment took 17.3728 seconds...
# --- PARCELLE 30756 ---
# collection
# 3 images founded...
# This image traitment took 14.1427 seconds...
# --- PARCELLE 30788 ---
# collection
# 3 images founded...
# This image traitment took 20.6512 seconds...
# --- PARCELLE 30812 ---
# collection
# 3 images founded...
# This image traitment took 16.0711 seconds...
# --- PARCELLE 30816 ---
# collection
# 3 images founded...
# This image traitment took 16.5636 seconds...
# --- PARCELLE 30820 ---
# collection
# 3 images founded...
# This image traitment took 15.9727 seconds...
# --- PARCELLE 30844 ---
# collection
# 3 images founded...
# This image traitment took 16.4705 seconds...
# --- PARCELLE 31072 ---
# collection
# 2 images founded...
# This image traitment took 16.4563 seconds...
# --- PARCELLE 31088 ---
# collection
# 2 images founded...
# This image traitment took 15.3405 seconds...
# --- PARCELLE 31132 ---
# collection
# 1 images founded...
# This image traitment took 17.8713 seconds...
# --- PARCELLE 31593 ---
# collection
# 3 images founded...
# This image traitment took 15.9468 seconds...
# --- PARCELLE 31597 ---
# collection
# 3 images founded...
# This image traitment took 16.7173 seconds...
# --- PARCELLE 31605 ---
# collection
# 3 images founded...
# This image traitment took 16.1868 seconds...
# --- PARCELLE 31773 ---
# collection
# 2 images founded...
# This image traitment took 21.591 seconds...
# --- PARCELLE 31845 ---
# collection
# 2 images founded...
# This image traitment took 15.3887 seconds...
# --- PARCELLE 31849 ---
# collection
# 2 images founded...
# This image traitment took 14.4622 seconds...
# --- PARCELLE 31861 ---
# collection
# 2 images founded...
# This image traitment took 19.8523 seconds...
# --- PARCELLE 32337 ---
# collection
# 3 images founded...
# This image traitment took 14.4448 seconds...
# --- PARCELLE 32361 ---
# collection
# 3 images founded...
# This image traitment took 14.2693 seconds...
# --- PARCELLE 32365 ---
# collection
# 3 images founded...
# This image traitment took 12.9917 seconds...
# --- PARCELLE 32629 ---
# collection
# 2 images founded...
# This image traitment took 13.6084 seconds...
# --- PARCELLE 32633 ---
# collection
# 2 images founded...
# This image traitment took 17.1941 seconds...
# --- PARCELLE 32669 ---
# collection
# 1 images founded...
# This image traitment took 15.7117 seconds...
# --- PARCELLE 33083 ---
# collection
# 3 images founded...
# This image traitment took 15.2898 seconds...
# --- PARCELLE 33135 ---
# collection
# 3 images founded...
# This image traitment took 16.409 seconds...
# --- PARCELLE 33139 ---
# collection
# 3 images founded...
# This image traitment took 15.8911 seconds...
# --- PARCELLE 33163 ---
# collection
# 3 images founded...
# This image traitment took 15.9616 seconds...
# --- PARCELLE 33263 ---
# collection
# 4 images founded...
# This image traitment took 15.9548 seconds...
# --- PARCELLE 33415 ---
# collection
# 2 images founded...
# This image traitment took 25.3131 seconds...
# --- PARCELLE 33419 ---
# collection
# 2 images founded...
# This image traitment took 16.0225 seconds...
# --- PARCELLE 33427 ---
# collection
# 2 images founded...
# This image traitment took 16.6521 seconds...
# --- PARCELLE 33909 ---
# collection
# 3 images founded...
# This image traitment took 17.4723 seconds...
# --- PARCELLE 33913 ---
# collection
# 3 images founded...
# This image traitment took 16.8248 seconds...
# --- PARCELLE 33917 ---
# collection
# 3 images founded...
# This image traitment took 19.2272 seconds...
# --- PARCELLE 33921 ---
# collection
# 3 images founded...
# This image traitment took 14.9767 seconds...
# --- PARCELLE 33925 ---
# collection
# 3 images founded...
# This image traitment took 14.6414 seconds...
# --- PARCELLE 33937 ---
# collection
# 3 images founded...
# This image traitment took 18.8039 seconds...
# --- PARCELLE 33941 ---
# collection
# 3 images founded...
# This image traitment took 12.4533 seconds...
# --- PARCELLE 34213 ---
# collection
# 2 images founded...
# This image traitment took 22.4071 seconds...
# --- PARCELLE 34237 ---
# collection
# 1 images founded...
# This image traitment took 17.0713 seconds...
# --- PARCELLE 34241 ---
# collection
# 1 images founded...
# This image traitment took 16.313 seconds...
# --- PARCELLE 34692 ---
# collection
# 3 images founded...
# This image traitment took 16.6137 seconds...
# --- PARCELLE 34696 ---
# collection
# 3 images founded...
# This image traitment took 21.3343 seconds...
# --- PARCELLE 34700 ---
# collection
# 3 images founded...
# This image traitment took 21.83 seconds...
# --- PARCELLE 34708 ---
# collection
# 3 images founded...
# This image traitment took 16.6642 seconds...
# --- PARCELLE 34712 ---
# collection
# 3 images founded...
# This image traitment took 15.8716 seconds...
# --- PARCELLE 35028 ---
# collection
# 1 images founded...
# This image traitment took 16.433 seconds...
# --- PARCELLE 35469 ---
# collection
# 3 images founded...
# This image traitment took 18.833 seconds...
# --- PARCELLE 35489 ---
# collection
# 3 images founded...
# This image traitment took 12.9216 seconds...
# --- PARCELLE 35729 ---
# collection
# 4 images founded...
# This image traitment took 22.2252 seconds...
# --- PARCELLE 35773 ---
# collection
# 2 images founded...
# This image traitment took 13.8832 seconds...
# --- PARCELLE 36260 ---
# collection
# 3 images founded...
# This image traitment took 15.6147 seconds...
# --- PARCELLE 36276 ---
# collection
# 3 images founded...
# This image traitment took 16.1528 seconds...
# --- PARCELLE 36280 ---
# collection
# 3 images founded...
# This image traitment took 13.3675 seconds...
# --- PARCELLE 36284 ---
# collection
# 3 images founded...
# This image traitment took 28.3145 seconds...
# --- PARCELLE 36288 ---
# collection
# 3 images founded...
# This image traitment took 13.1459 seconds...
# --- PARCELLE 36296 ---
# collection
# 3 images founded...
# This image traitment took 15.5882 seconds...
# --- PARCELLE 36488 ---
# collection
# 4 images founded...
# This image traitment took 16.3146 seconds...
# --- PARCELLE 36524 ---
# collection
# 4 images founded...
# This image traitment took 16.4254 seconds...
# --- PARCELLE 36564 ---
# collection
# 2 images founded...
# This image traitment took 15.7321 seconds...
# --- PARCELLE 36568 ---
# collection
# 2 images founded...
# This image traitment took 18.4283 seconds...
# --- PARCELLE 36592 ---
# collection
# 2 images founded...
# This image traitment took 25.3222 seconds...
# --- PARCELLE 37070 ---
# collection
# 3 images founded...
# This image traitment took 17.7297 seconds...
# --- PARCELLE 37074 ---
# collection
# 3 images founded...
# This image traitment took 20.8996 seconds...
# --- PARCELLE 37090 ---
# collection
# 3 images founded...
# This image traitment took 21.2203 seconds...
# --- PARCELLE 37098 ---
# collection
# 3 images founded...
# This image traitment took 19.5555 seconds...
# --- PARCELLE 37346 ---
# collection
# 4 images founded...
# This image traitment took 21.3854 seconds...
# --- PARCELLE 37382 ---
# collection
# 2 images founded...
# This image traitment took 16.3004 seconds...
# --- PARCELLE 37414 ---
# collection
# 1 images founded...
# This image traitment took 16.0646 seconds...
# --- PARCELLE 37835 ---
# collection
# 3 images founded...
# This image traitment took 20.0194 seconds...
# --- PARCELLE 37867 ---
# collection
# 3 images founded...
# This image traitment took 19.7482 seconds...
# --- PARCELLE 37883 ---
# collection
# 3 images founded...
# This image traitment took 13.3812 seconds...
# --- PARCELLE 37891 ---
# collection
# 3 images founded...
# This image traitment took 14.6486 seconds...
# --- PARCELLE 37895 ---
# collection
# 3 images founded...
# This image traitment took 22.3114 seconds...
# --- PARCELLE 38087 ---
# collection
# 4 images founded...
# This image traitment took 24.936 seconds...
# --- PARCELLE 38103 ---
# collection
# 4 images founded...
# This image traitment took 16.6027 seconds...
# --- PARCELLE 38107 ---
# collection
# 2 images founded...
# This image traitment took 24.8138 seconds...
# --- PARCELLE 38111 ---
# collection
# 4 images founded...
# This image traitment took 26.4619 seconds...
# --- PARCELLE 38135 ---
# collection
# 4 images founded...
# This image traitment took 17.8813 seconds...
# --- PARCELLE 38151 ---
# collection
# 4 images founded...
# This image traitment took 16.6404 seconds...
# --- PARCELLE 38155 ---
# collection
# 4 images founded...
# This image traitment took 25.5703 seconds...
# --- PARCELLE 38167 ---
# collection
# 2 images founded...
# This image traitment took 21.3146 seconds...
# --- PARCELLE 38171 ---
# collection
# 2 images founded...
# This image traitment took 16.8221 seconds...
# --- PARCELLE 38227 ---
# collection
# 1 images founded...
# This image traitment took 16.8238 seconds...
# --- PARCELLE 38657 ---
# collection
# 3 images founded...
# This image traitment took 13.7719 seconds...
# --- PARCELLE 38769 ---
# collection
# 3 images founded...
# This image traitment took 34.0154 seconds...
# --- PARCELLE 38805 ---
# collection
# 2 images founded...
# This image traitment took 14.3343 seconds...
# --- PARCELLE 38905 ---
# collection
# 4 images founded...
# This image traitment took 16.8216 seconds...
# --- PARCELLE 38945 ---
# collection
# 4 images founded...
# This image traitment took 18.8427 seconds...
# --- PARCELLE 38961 ---
# collection
# 4 images founded...
# This image traitment took 16.694 seconds...
# --- PARCELLE 38973 ---
# collection
# 2 images founded...
# This image traitment took 29.9341 seconds...
# --- PARCELLE 38977 ---
# collection
# 2 images founded...
# This image traitment took 22.8563 seconds...
# --- PARCELLE 39005 ---
# collection
# 1 images founded...
# This image traitment took 25.75 seconds...
# --- PARCELLE 39009 ---
# collection
# 1 images founded...
# This image traitment took 15.8241 seconds...
# --- PARCELLE 39029 ---
# collection
# 1 images founded...
# This image traitment took 17.7126 seconds...
# --- PARCELLE 39446 ---
# collection
# 3 images founded...
# This image traitment took 21.9532 seconds...
# --- PARCELLE 39474 ---
# collection
# 3 images founded...
# This image traitment took 16.8612 seconds...
# --- PARCELLE 39482 ---
# collection
# 3 images founded...
# This image traitment took 20.3079 seconds...
# --- PARCELLE 39574 ---
# collection
# 3 images founded...
# This image traitment took 15.6065 seconds...
# --- PARCELLE 39710 ---
# collection
# 4 images founded...
# This image traitment took 15.1692 seconds...
# --- PARCELLE 39750 ---
# collection
# 4 images founded...
# This image traitment took 14.7945 seconds...
# --- PARCELLE 39754 ---
# collection
# 4 images founded...
# This image traitment took 17.0334 seconds...
# --- PARCELLE 39762 ---
# collection
# 4 images founded...
# This image traitment took 14.6084 seconds...
# --- PARCELLE 39774 ---
# collection
# 4 images founded...
# This image traitment took 23.8531 seconds...
# --- PARCELLE 39778 ---
# collection
# 4 images founded...
# This image traitment took 18.1059 seconds...
# --- PARCELLE 39822 ---
# collection
# 1 images founded...
# This image traitment took 16.2497 seconds...
# --- PARCELLE 39838 ---
# collection
# 1 images founded...
# This image traitment took 18.9825 seconds...
# --- PARCELLE 40261 ---
# collection
# 3 images founded...
# This image traitment took 16.6191 seconds...
# --- PARCELLE 40285 ---
# collection
# 3 images founded...
# This image traitment took 18.1863 seconds...
# --- PARCELLE 40313 ---
# collection
# 3 images founded...
# This image traitment took 20.5568 seconds...
# --- PARCELLE 40517 ---
# collection
# 4 images founded...
# This image traitment took 27.2876 seconds...
# --- PARCELLE 40569 ---
# collection
# 4 images founded...
# This image traitment took 22.1959 seconds...
# --- PARCELLE 40581 ---
# collection
# 4 images founded...
# This image traitment took 16.1258 seconds...
# --- PARCELLE 40593 ---
# collection
# 4 images founded...
# This image traitment took 20.218 seconds...
# --- PARCELLE 40641 ---
# collection
# 1 images founded...
# This image traitment took 24.8588 seconds...
# --- PARCELLE 40661 ---
# collection
# 1 images founded...
# This image traitment took 18.6172 seconds...
# --- PARCELLE 41134 ---
# collection
# 3 images founded...
# This image traitment took 15.319 seconds...
# --- PARCELLE 41142 ---
# collection
# 3 images founded...
# This image traitment took 24.5311 seconds...
# --- PARCELLE 41162 ---
# collection
# 3 images founded...
# This image traitment took 19.4761 seconds...
# --- PARCELLE 41222 ---
# collection
# 2 images founded...
# This image traitment took 18.8658 seconds...
# --- PARCELLE 41230 ---
# collection
# 2 images founded...
# This image traitment took 20.53 seconds...
# --- PARCELLE 41254 ---
# collection
# 2 images founded...
# This image traitment took 20.8103 seconds...
# --- PARCELLE 41338 ---
# collection
# 4 images founded...
# This image traitment took 15.4944 seconds...
# --- PARCELLE 41394 ---
# collection
# 4 images founded...
# This image traitment took 14.4719 seconds...
# --- PARCELLE 41418 ---
# collection
# 4 images founded...
# This image traitment took 15.5723 seconds...
# --- PARCELLE 41430 ---
# collection
# 4 images founded...
# This image traitment took 17.8593 seconds...
# --- PARCELLE 41470 ---
# collection
# 1 images founded...
# This image traitment took 22.907 seconds...
# --- PARCELLE 41933 ---
# collection
# 3 images founded...
# This image traitment took 17.0715 seconds...
# --- PARCELLE 41973 ---
# collection
# 3 images founded...
# This image traitment took 22.9053 seconds...
# --- PARCELLE 42185 ---
# collection
# 4 images founded...
# This image traitment took 25.6032 seconds...
# --- PARCELLE 42193 ---
# collection
# 4 images founded...
# This image traitment took 14.871 seconds...
# --- PARCELLE 42201 ---
# collection
# 4 images founded...
# This image traitment took 15.7734 seconds...
# --- PARCELLE 42217 ---
# collection
# 4 images founded...
# This image traitment took 18.6118 seconds...
# --- PARCELLE 42241 ---
# collection
# 4 images founded...
# This image traitment took 13.2035 seconds...
# --- PARCELLE 42249 ---
# collection
# 4 images founded...
# This image traitment took 17.2883 seconds...
# --- PARCELLE 42253 ---
# collection
# 4 images founded...
# This image traitment took 16.7966 seconds...
# --- PARCELLE 42265 ---
# collection
# 4 images founded...
# This image traitment took 19.8958 seconds...
# --- PARCELLE 42289 ---
# collection
# 1 images founded...
# This image traitment took 17.4671 seconds...
# --- PARCELLE 42301 ---
# collection
# 1 images founded...
# This image traitment took 16.6352 seconds...
# --- PARCELLE 42786 ---
# collection
# 3 images founded...
# This image traitment took 16.9499 seconds...
# --- PARCELLE 43022 ---
# collection
# 4 images founded...
# This image traitment took 23.948 seconds...
# --- PARCELLE 43026 ---
# collection
# 4 images founded...
# This image traitment took 29.1958 seconds...
# --- PARCELLE 43038 ---
# collection
# 4 images founded...
# This image traitment took 21.4987 seconds...
# --- PARCELLE 43046 ---
# collection
# 4 images founded...
# This image traitment took 16.3691 seconds...
# --- PARCELLE 43062 ---
# collection
# 4 images founded...
# This image traitment took 19.337 seconds...
# --- PARCELLE 43070 ---
# collection
# 4 images founded...
# This image traitment took 22.3766 seconds...
# --- PARCELLE 43098 ---
# collection
# 4 images founded...
# This image traitment took 21.8996 seconds...
# --- PARCELLE 43102 ---
# collection
# 4 images founded...
# This image traitment took 20.3974 seconds...
# --- PARCELLE 43114 ---
# collection
# 2 images founded...
# This image traitment took 26.1015 seconds...
# --- PARCELLE 43122 ---
# collection
# 1 images founded...
# This image traitment took 20.1047 seconds...
# --- PARCELLE 43126 ---
# collection
# 1 images founded...
# This image traitment took 17.9373 seconds...
# --- PARCELLE 43866 ---
# collection
# 4 images founded...
# This image traitment took 37.1047 seconds...
# --- PARCELLE 43906 ---
# collection
# 4 images founded...
# This image traitment took 13.6888 seconds...
# --- PARCELLE 43910 ---
# collection
# 4 images founded...
# This image traitment took 15.9129 seconds...
# --- PARCELLE 43934 ---
# collection
# 4 images founded...
# This image traitment took 28.782 seconds...
# --- PARCELLE 43942 ---
# collection
# 4 images founded...
# This image traitment took 29.3347 seconds...
# --- PARCELLE 43958 ---
# collection
# 2 images founded...
# This image traitment took 23.667 seconds...
# --- PARCELLE 43962 ---
# collection
# 1 images founded...
# This image traitment took 19.6633 seconds...
# --- PARCELLE 43986 ---
# collection
# 1 images founded...
# This image traitment took 17.4485 seconds...
# --- PARCELLE 44699 ---
# collection
# 4 images founded...
# This image traitment took 14.4143 seconds...
# --- PARCELLE 44703 ---
# collection
# 4 images founded...
# This image traitment took 19.4267 seconds...
# --- PARCELLE 44723 ---
# collection
# 4 images founded...
# This image traitment took 11.0282 seconds...
# --- PARCELLE 44727 ---
# collection
# 4 images founded...
# This image traitment took 15.8297 seconds...
# --- PARCELLE 44747 ---
# collection
# 4 images founded...
# This image traitment took 14.9789 seconds...
# --- PARCELLE 44751 ---
# collection
# 4 images founded...
# This image traitment took 16.4406 seconds...
# --- PARCELLE 44779 ---
# collection
# 4 images founded...
# This image traitment took 16.9129 seconds...
# --- PARCELLE 44799 ---
# collection
# 1 images founded...
# This image traitment took 22.9348 seconds...
# --- PARCELLE 44815 ---
# collection
# 1 images founded...
# This image traitment took 16.8484 seconds...
# --- PARCELLE 44835 ---
# collection
# 1 images founded...
# This image traitment took 18.9059 seconds...
# --- PARCELLE 45409 ---
# collection
# 3 images founded...
# This image traitment took 16.1567 seconds...
# --- PARCELLE 45413 ---
# collection
# 3 images founded...
# This image traitment took 15.9336 seconds...
# --- PARCELLE 45497 ---
# collection
# 4 images founded...
# This image traitment took 15.3198 seconds...
# --- PARCELLE 45509 ---
# collection
# 4 images founded...
# This image traitment took 16.6713 seconds...
# --- PARCELLE 45557 ---
# collection
# 4 images founded...
# This image traitment took 17.9723 seconds...
# --- PARCELLE 45561 ---
# collection
# 4 images founded...
# This image traitment took 14.1793 seconds...
# --- PARCELLE 45569 ---
# collection
# 4 images founded...
# This image traitment took 16.0304 seconds...
# --- PARCELLE 45573 ---
# collection
# 4 images founded...
# This image traitment took 14.8584 seconds...
# --- PARCELLE 45589 ---
# collection
# 4 images founded...
# This image traitment took 14.7906 seconds...
# --- PARCELLE 45641 ---
# collection
# 2 images founded...
# This image traitment took 15.6509 seconds...
# --- PARCELLE 45657 ---
# collection
# 1 images founded...
# This image traitment took 17.5735 seconds...
# --- PARCELLE 45665 ---
# collection
# 1 images founded...
# This image traitment took 13.5288 seconds...
# --- PARCELLE 45673 ---
# collection
# 1 images founded...
# This image traitment took 11.1272 seconds...
# --- PARCELLE 45681 ---
# collection
# 1 images founded...
# This image traitment took 13.7336 seconds...
# --- PARCELLE 46109 ---
# collection
# 3 images founded...
# This image traitment took 16.5055 seconds...
# --- PARCELLE 46169 ---
# collection
# 3 images founded...
# This image traitment took 15.0921 seconds...
# --- PARCELLE 46257 ---
# collection
# 3 images founded...
# This image traitment took 15.8736 seconds...
# --- PARCELLE 46401 ---
# collection
# 4 images founded...
# This image traitment took 21.5953 seconds...
# --- PARCELLE 46417 ---
# collection
# 4 images founded...
# This image traitment took 16.4763 seconds...
# --- PARCELLE 46421 ---
# collection
# 4 images founded...
# This image traitment took 15.7865 seconds...
# --- PARCELLE 46445 ---
# collection
# 4 images founded...
# This image traitment took 15.7071 seconds...
# --- PARCELLE 46469 ---
# collection
# 4 images founded...
# This image traitment took 15.5404 seconds...
# --- PARCELLE 46501 ---
# collection
# 1 images founded...
# This image traitment took 16.3447 seconds...
# --- PARCELLE 46513 ---
# collection
# 1 images founded...
# This image traitment took 15.687 seconds...
# --- PARCELLE 47031 ---
# collection
# 3 images founded...
# This image traitment took 15.1762 seconds...
# --- PARCELLE 47271 ---
# collection
# 4 images founded...
# This image traitment took 14.608 seconds...
# --- PARCELLE 47279 ---
# collection
# 4 images founded...
# This image traitment took 15.6163 seconds...
# --- PARCELLE 47283 ---
# collection
# 4 images founded...
# This image traitment took 15.2469 seconds...
# --- PARCELLE 47307 ---
# collection
# 4 images founded...
# This image traitment took 14.7174 seconds...
# --- PARCELLE 47311 ---
# collection
# 4 images founded...
# This image traitment took 12.102 seconds...
# --- PARCELLE 47327 ---
# collection
# 4 images founded...
# This image traitment took 12.9535 seconds...
# --- PARCELLE 47387 ---
# collection
# 1 images founded...
# This image traitment took 11.6969 seconds...
# --- PARCELLE 47391 ---
# collection
# 1 images founded...
# This image traitment took 11.8427 seconds...
# --- PARCELLE 47407 ---
# collection
# 1 images founded...
# This image traitment took 15.2001 seconds...
# --- PARCELLE 47927 ---
# collection
# 3 images founded...
# This image traitment took 16.1814 seconds...
# --- PARCELLE 48079 ---
# collection
# 2 images founded...
# This image traitment took 16.3845 seconds...
# --- PARCELLE 48087 ---
# collection
# 2 images founded...
# This image traitment took 15.7789 seconds...
# --- PARCELLE 48191 ---
# collection
# 4 images founded...
# This image traitment took 16.4688 seconds...
# --- PARCELLE 48231 ---
# collection
# 4 images founded...
# This image traitment took 15.779 seconds...
# --- PARCELLE 48271 ---
# collection
# 4 images founded...
# This image traitment took 15.4406 seconds...
# --- PARCELLE 48279 ---
# collection
# 4 images founded...
# This image traitment took 15.9211 seconds...
# --- PARCELLE 48319 ---
# collection
# 1 images founded...
# This image traitment took 16.5584 seconds...
# --- PARCELLE 48323 ---
# collection
# 1 images founded...
# This image traitment took 15.0904 seconds...
# --- PARCELLE 48327 ---
# collection
# 1 images founded...
# This image traitment took 15.6471 seconds...
# --- PARCELLE 48363 ---
# collection
# 3 images founded...
# This image traitment took 15.8199 seconds...
# --- PARCELLE 48897 ---
# collection
# 3 images founded...
# This image traitment took 15.8557 seconds...
# --- PARCELLE 49021 ---
# collection
# 2 images founded...
# This image traitment took 16.031 seconds...
# --- PARCELLE 49029 ---
# collection
# 2 images founded...
# This image traitment took 15.3271 seconds...
# --- PARCELLE 49069 ---
# collection
# 4 images founded...
# This image traitment took 15.21 seconds...
# --- PARCELLE 49117 ---
# collection
# 4 images founded...
# This image traitment took 14.6698 seconds...
# --- PARCELLE 49205 ---
# collection
# 4 images founded...
# This image traitment took 13.0675 seconds...
# --- PARCELLE 49245 ---
# collection
# 1 images founded...
# This image traitment took 12.0534 seconds...
# --- PARCELLE 49281 ---
# collection
# 3 images founded...
# This image traitment took 11.9777 seconds...
# --- PARCELLE 49305 ---
# collection
# 3 images founded...
# This image traitment took 14.6797 seconds...
# --- PARCELLE 49805 ---
# collection
# 3 images founded...
# This image traitment took 14.6782 seconds...
# --- PARCELLE 49829 ---
# collection
# 3 images founded...
# This image traitment took 15.6022 seconds...
# --- PARCELLE 49973 ---
# collection
# 2 images founded...
# This image traitment took 15.8103 seconds...
# --- PARCELLE 50069 ---
# collection
# 4 images founded...
# This image traitment took 16.3511 seconds...
# --- PARCELLE 50073 ---
# collection
# 4 images founded...
# This image traitment took 16.6235 seconds...
# --- PARCELLE 50109 ---
# collection
# 4 images founded...
# This image traitment took 16.0646 seconds...
# --- PARCELLE 50145 ---
# collection
# 4 images founded...
# This image traitment took 15.4975 seconds...
# --- PARCELLE 50149 ---
# collection
# 4 images founded...
# This image traitment took 15.4351 seconds...
# --- PARCELLE 50157 ---
# collection
# 4 images founded...
# This image traitment took 15.2912 seconds...
# --- PARCELLE 50217 ---
# collection
# 1 images founded...
# This image traitment took 16.3517 seconds...
# --- PARCELLE 50253 ---
# collection
# 3 images founded...
# This image traitment took 14.5816 seconds...
# --- PARCELLE 50917 ---
# collection
# 3 images founded...
# This image traitment took 15.5161 seconds...
# --- PARCELLE 50921 ---
# collection
# 3 images founded...
# This image traitment took 14.197 seconds...
# --- PARCELLE 50925 ---
# collection
# 3 images founded...
# This image traitment took 13.6861 seconds...
# --- PARCELLE 50933 ---
# collection
# 2 images founded...
# This image traitment took 18.7261 seconds...
# --- PARCELLE 50941 ---
# collection
# 2 images founded...
# This image traitment took 14.0744 seconds...
# --- PARCELLE 50949 ---
# collection
# 2 images founded...
# This image traitment took 10.7443 seconds...
# --- PARCELLE 51057 ---
# collection
# 4 images founded...
# This image traitment took 11.9842 seconds...
# --- PARCELLE 51069 ---
# collection
# 4 images founded...
# This image traitment took 11.5386 seconds...
# --- PARCELLE 51081 ---
# collection
# 4 images founded...
# This image traitment took 14.7364 seconds...
# --- PARCELLE 51089 ---
# collection
# 4 images founded...
# This image traitment took 24.9856 seconds...
# --- PARCELLE 51093 ---
# collection
# 4 images founded...
# This image traitment took 17.4338 seconds...
# --- PARCELLE 51181 ---
# collection
# 1 images founded...
# This image traitment took 16.5928 seconds...
# --- PARCELLE 51185 ---
# collection
# 1 images founded...
# This image traitment took 16.5669 seconds...
# --- PARCELLE 51189 ---
# collection
# 1 images founded...
# This image traitment took 16.4273 seconds...
# --- PARCELLE 51193 ---
# collection
# 1 images founded...
# This image traitment took 15.3881 seconds...
# --- PARCELLE 51197 ---
# collection
# 1 images founded...
# This image traitment took 16.0713 seconds...
# --- PARCELLE 51213 ---
# collection
# 3 images founded...
# This image traitment took 16.3609 seconds...
# --- PARCELLE 51225 ---
# collection
# 3 images founded...
# This image traitment took 16.2745 seconds...
# --- PARCELLE 51237 ---
# collection
# 3 images founded...
# This image traitment took 14.777 seconds...
# --- PARCELLE 51805 ---
# collection
# 3 images founded...
# This image traitment took 16.7009 seconds...
# ...
# --- PARCELLE 157046 ---
# collection
# 1 images founded...
# This image traitment took 16.1095 seconds...
# --- PARCELLE 157315 ---
# collection
# 2 images founded...
# This image traitment took 14.7621 seconds...
# --- PARCELLE 157327 ---
# collection
# 2 images founded...
# This image traitment took 16.0002 seconds...
# --- PARCELLE 157331 ---
# collection
# 2 images founded...
# This image traitment took 14.943 seconds...
# --- PARCELLE 157335 ---
# collection
# 2 images founded...
# This image traitment took 14.8348 seconds...
# --- PARCELLE 157371 ---
# collection
# 1 images founded...
# This image traitment took 13.0671 seconds...
# --- PARCELLE 157383 ---
# collection
# 1 images founded...
# This image traitment took 11.1516 seconds...
# --- PARCELLE 157455 ---
# collection
# 2 images founded...
# This image traitment took 11.3706 seconds...
# --- PARCELLE 157480 ---
# collection
# 2 images founded...
# This image traitment took 12.3331 seconds...
# --- PARCELLE 157484 ---
# collection
# 1 images founded...
# This image traitment took 11.2839 seconds...
# --- PARCELLE 157504 ---
# collection
# 1 images founded...
# This image traitment took 11.405 seconds...
# --- PARCELLE 157508 ---
# collection
# 1 images founded...
# This image traitment took 14.6678 seconds...
# --- PARCELLE 157759 ---
# collection
# 2 images founded...
# This image traitment took 12.4317 seconds...
# --- PARCELLE 157763 ---
# collection
# 2 images founded...
# This image traitment took 14.0376 seconds...
# --- PARCELLE 157767 ---
# collection
# 2 images founded...
# This image traitment took 13.1819 seconds...
# --- PARCELLE 157775 ---
# collection
# 2 images founded...
# This image traitment took 14.5387 seconds...
# --- PARCELLE 157779 ---
# collection
# 2 images founded...
# This image traitment took 11.6082 seconds...
# --- PARCELLE 157787 ---
# collection
# 2 images founded...
# This image traitment took 14.1464 seconds...
# --- PARCELLE 157929 ---
# collection
# 1 images founded...
# This image traitment took 14.0454 seconds...
# --- PARCELLE 157933 ---
# collection
# 1 images founded...
# This image traitment took 13.0265 seconds...
# --- PARCELLE 157941 ---
# collection
# 1 images founded...
# This image traitment took 12.4455 seconds...
# --- PARCELLE 157949 ---
# collection
# 1 images founded...
# This image traitment took 12.2373 seconds...
# --- PARCELLE 157953 ---
# collection
# 1 images founded...
# This image traitment took 12.4944 seconds...
# --- PARCELLE 157957 ---
# collection
# 1 images founded...
# This image traitment took 11.7493 seconds...
# --- PARCELLE 158187 ---
# collection
# 2 images founded...
# This image traitment took 12.4062 seconds...
# --- PARCELLE 158195 ---
# collection
# 2 images founded...
# This image traitment took 15.8767 seconds...
# --- PARCELLE 158199 ---
# collection
# 2 images founded...
# This image traitment took 13.1708 seconds...
# --- PARCELLE 158203 ---
# collection
# 2 images founded...
# This image traitment took 15.1423 seconds...
# --- PARCELLE 158207 ---
# collection
# 2 images founded...
# This image traitment took 13.7235 seconds...
# --- PARCELLE 158211 ---
# collection
# 2 images founded...
# This image traitment took 11.297 seconds...
# --- PARCELLE 158231 ---
# collection
# 2 images founded...
# This image traitment took 14.0414 seconds...
# --- PARCELLE 158275 ---
# collection
# 1 images founded...
# This image traitment took 14.1478 seconds...
# --- PARCELLE 158361 ---
# collection
# 1 images founded...
# This image traitment took 10.94 seconds...
# --- PARCELLE 158365 ---
# collection
# 1 images founded...
# This image traitment took 14.1063 seconds...
# --- PARCELLE 158373 ---
# collection
# 1 images founded...
# This image traitment took 15.717 seconds...
# --- PARCELLE 158377 ---
# collection
# 1 images founded...
# This image traitment took 15.556 seconds...
# --- PARCELLE 158381 ---
# collection
# 1 images founded...
# This image traitment took 16.0653 seconds...
# --- PARCELLE 158385 ---
# collection
# 1 images founded...
# This image traitment took 15.7036 seconds...
# --- PARCELLE 158620 ---
# collection
# 2 images founded...
# This image traitment took 15.2173 seconds...
# --- PARCELLE 158632 ---
# collection
# 2 images founded...
# This image traitment took 16.25 seconds...
# --- PARCELLE 158636 ---
# collection
# 2 images founded...
# This image traitment took 16.8485 seconds...
# --- PARCELLE 158652 ---
# collection
# 2 images founded...
# This image traitment took 15.1522 seconds...
# --- PARCELLE 158696 ---
# collection
# 1 images founded...
# This image traitment took 14.2097 seconds...
# --- PARCELLE 158780 ---
# collection
# 1 images founded...
# This image traitment took 13.4753 seconds...
# --- PARCELLE 158796 ---
# collection
# 1 images founded...
# This image traitment took 13.2761 seconds...
# --- PARCELLE 158804 ---
# collection
# 1 images founded...
# This image traitment took 16.1467 seconds...
# --- PARCELLE 159039 ---
# collection
# 2 images founded...
# This image traitment took 15.4666 seconds...
# --- PARCELLE 159043 ---
# collection
# 2 images founded...
# This image traitment took 15.125 seconds...
# --- PARCELLE 159047 ---
# collection
# 2 images founded...
# This image traitment took 15.4137 seconds...
# --- PARCELLE 159063 ---
# collection
# 2 images founded...
# This image traitment took 12.4312 seconds...
# --- PARCELLE 159067 ---
# collection
# 2 images founded...
# This image traitment took 12.562 seconds...
# --- PARCELLE 159115 ---
# collection
# 1 images founded...
# This image traitment took 11.4025 seconds...
# --- PARCELLE 159119 ---
# collection
# 1 images founded...
# This image traitment took 12.5203 seconds...
# --- PARCELLE 159198 ---
# collection
# 1 images founded...
# This image traitment took 10.1749 seconds...
# --- PARCELLE 159202 ---
# collection
# 1 images founded...
# This image traitment took 15.1945 seconds...
# --- PARCELLE 159214 ---
# collection
# 1 images founded...
# This image traitment took 16.0166 seconds...
# --- PARCELLE 159222 ---
# collection
# 1 images founded...
# This image traitment took 16.3836 seconds...
# --- PARCELLE 159435 ---
# collection
# 2 images founded...
# This image traitment took 16.4078 seconds...
# --- PARCELLE 159439 ---
# collection
# 2 images founded...
# This image traitment took 15.8415 seconds...
# --- PARCELLE 159443 ---
# collection
# 2 images founded...
# This image traitment took 15.9564 seconds...
# --- PARCELLE 159447 ---
# collection
# 2 images founded...
# This image traitment took 15.9718 seconds...
# --- PARCELLE 159451 ---
# collection
# 2 images founded...
# This image traitment took 14.0474 seconds...
# --- PARCELLE 159455 ---
# collection
# 2 images founded...
# This image traitment took 20.6517 seconds...
# --- PARCELLE 159463 ---
# collection
# 2 images founded...
# This image traitment took 15.2848 seconds...
# --- PARCELLE 159471 ---
# collection
# 2 images founded...
# This image traitment took 17.4455 seconds...
# --- PARCELLE 159519 ---
# collection
# 1 images founded...
# This image traitment took 15.6236 seconds...
# --- PARCELLE 159612 ---
# collection
# 1 images founded...
# This image traitment took 15.5313 seconds...
# --- PARCELLE 159839 ---
# collection
# 2 images founded...
# This image traitment took 15.106 seconds...
# --- PARCELLE 159843 ---
# collection
# 2 images founded...
# This image traitment took 14.8816 seconds...
# --- PARCELLE 159867 ---
# collection
# 2 images founded...
# This image traitment took 15.2836 seconds...
# --- PARCELLE 159871 ---
# collection
# 2 images founded...
# This image traitment took 13.8182 seconds...
# --- PARCELLE 159875 ---
# collection
# 2 images founded...
# This image traitment took 14.5808 seconds...
# --- PARCELLE 159879 ---
# collection
# 2 images founded...
# This image traitment took 11.5234 seconds...
# --- PARCELLE 159883 ---
# collection
# 2 images founded...
# This image traitment took 15.3879 seconds...
# --- PARCELLE 160006 ---
# collection
# 1 images founded...
# This image traitment took 15.6853 seconds...
# --- PARCELLE 160010 ---
# collection
# 1 images founded...
# This image traitment took 15.4963 seconds...
# --- PARCELLE 160022 ---
# collection
# 1 images founded...
# This image traitment took 14.6235 seconds...
# --- PARCELLE 160030 ---
# collection
# 1 images founded...
# This image traitment took 14.646 seconds...
# --- PARCELLE 160236 ---
# collection
# 2 images founded...
# This image traitment took 13.321 seconds...
# --- PARCELLE 160252 ---
# collection
# 2 images founded...
# This image traitment took 14.354 seconds...
# --- PARCELLE 160272 ---
# collection
# 2 images founded...
# This image traitment took 15.476 seconds...
# --- PARCELLE 160280 ---
# collection
# 1 images founded...
# This image traitment took 12.9706 seconds...
# --- PARCELLE 160356 ---
# collection
# 2 images founded...
# This image traitment took 14.7516 seconds...
# --- PARCELLE 160396 ---
# collection
# 1 images founded...
# This image traitment took 16.108 seconds...
# --- PARCELLE 160400 ---
# collection
# 1 images founded...
# This image traitment took 15.2524 seconds...
# --- PARCELLE 160404 ---
# collection
# 1 images founded...
# This image traitment took 12.7813 seconds...
# --- PARCELLE 160408 ---
# collection
# 1 images founded...
# This image traitment took 17.4971 seconds...
# --- PARCELLE 160420 ---
# collection
# 1 images founded...
# This image traitment took 14.2712 seconds...
# --- PARCELLE 160640 ---
# collection
# 2 images founded...
# This image traitment took 14.1088 seconds...
# --- PARCELLE 160648 ---
# collection
# 2 images founded...
# This image traitment took 13.6454 seconds...
# --- PARCELLE 160740 ---
# collection
# 2 images founded...
# This image traitment took 11.7888 seconds...
# --- PARCELLE 160784 ---
# collection
# 1 images founded...
# This image traitment took 12.7076 seconds...
# --- PARCELLE 160788 ---
# collection
# 1 images founded...
# This image traitment took 11.1852 seconds...
# --- PARCELLE 160792 ---
# collection
# 1 images founded...
# This image traitment took 11.1638 seconds...
# --- PARCELLE 160808 ---
# collection
# 1 images founded...
# This image traitment took 10.7183 seconds...
# --- PARCELLE 161168 ---
# collection
# 2 images founded...
# This image traitment took 14.6061 seconds...
# --- PARCELLE 161172 ---
# collection
# 1 images founded...
# This image traitment took 15.6173 seconds...
# --- PARCELLE 161176 ---
# collection
# 1 images founded...
# This image traitment took 16.2206 seconds...
# --- PARCELLE 161196 ---
# collection
# 1 images founded...
# This image traitment took 16.2714 seconds...
# --- PARCELLE 161200 ---
# collection
# 1 images founded...
# This image traitment took 15.9331 seconds...
# --- PARCELLE 161416 ---
# collection
# 2 images founded...
# This image traitment took 16.3439 seconds...
# --- PARCELLE 161420 ---
# collection
# 2 images founded...
# This image traitment took 16.4588 seconds...
# --- PARCELLE 161516 ---
# collection
# 2 images founded...
# This image traitment took 15.2923 seconds...
# --- PARCELLE 161567 ---
# collection
# 1 images founded...
# This image traitment took 14.6331 seconds...
# --- PARCELLE 161806 ---
# collection
# 2 images founded...
# This image traitment took 15.3229 seconds...
# --- PARCELLE 161810 ---
# collection
# 2 images founded...
# This image traitment took 15.913 seconds...
# --- PARCELLE 161906 ---
# collection
# 2 images founded...
# This image traitment took 15.9175 seconds...
# --- PARCELLE 161951 ---
# collection
# 1 images founded...
# This image traitment took 15.144 seconds...
# --- PARCELLE 162185 ---
# collection
# 2 images founded...
# This image traitment took 16.3663 seconds...
# --- PARCELLE 162193 ---
# collection
# 2 images founded...
# This image traitment took 13.9554 seconds...
# --- PARCELLE 162197 ---
# collection
# 2 images founded...
# This image traitment took 14.3561 seconds...
# --- PARCELLE 162281 ---
# collection
# 2 images founded...
# This image traitment took 12.8071 seconds...
# --- PARCELLE 162314 ---
# collection
# 1 images founded...
# This image traitment took 11.6206 seconds...
# --- PARCELLE 162519 ---
# collection
# 2 images founded...
# This image traitment took 12.9665 seconds...
# --- PARCELLE 162535 ---
# collection
# 2 images founded...
# This image traitment took 12.6003 seconds...
# --- PARCELLE 162657 ---
# collection
# 1 images founded...
# This image traitment took 14.6502 seconds...
# --- PARCELLE 162846 ---
# collection
# 2 images founded...
# This image traitment took 14.6094 seconds...
# --- PARCELLE 162959 ---
# collection
# 1 images founded...
# This image traitment took 14.6597 seconds...
# --- PARCELLE 162963 ---
# collection
# 1 images founded...
# This image traitment took 14.9583 seconds...
# --- PARCELLE 163132 ---
# collection
# 2 images founded...
# This image traitment took 14.8119 seconds...
# --- PARCELLE 163136 ---
# collection
# 2 images founded...
# This image traitment took 15.5618 seconds...
# --- PARCELLE 163420 ---
# collection
# 2 images founded...
# This image traitment took 16.305 seconds...
# --- PARCELLE 163508 ---
# collection
# 1 images founded...
# This image traitment took 14.0877 seconds...
# --- PARCELLE 163516 ---
# collection
# 1 images founded...
# This image traitment took 15.359 seconds...
# --- PARCELLE 163520 ---
# collection
# 1 images founded...
# This image traitment took 15.3552 seconds...
# --- PARCELLE 163742 ---
# collection
# 1 images founded...
# This image traitment took 14.4074 seconds...
# --- PARCELLE 163746 ---
# collection
# 1 images founded...
# This image traitment took 13.5954 seconds...
# --- PARCELLE 163754 ---
# collection
# 1 images founded...
# This image traitment took 14.1301 seconds...
# --- PARCELLE 163883 ---
# collection
# 2 images founded...
# This image traitment took 14.6692 seconds...
# --- PARCELLE 163968 ---
# collection
# 1 images founded...
# This image traitment took 15.6068 seconds...
# --- PARCELLE 163972 ---
# collection
# 1 images founded...
# This image traitment took 13.745 seconds...
# --- PARCELLE 163980 ---
# collection
# 1 images founded...
# This image traitment took 13.9429 seconds...
# --- PARCELLE 164193 ---
# collection
# 1 images founded...
# This image traitment took 13.0325 seconds...
# --- PARCELLE 164205 ---
# collection
# 1 images founded...
# This image traitment took 12.3663 seconds...
# --- PARCELLE 164319 ---
# collection
# 2 images founded...
# This image traitment took 10.4504 seconds...
# --- PARCELLE 164392 ---
# collection
# 1 images founded...
# This image traitment took 12.6204 seconds...
# --- PARCELLE 164400 ---
# collection
# 1 images founded...
# This image traitment took 13.624 seconds...
# --- PARCELLE 164404 ---
# collection
# 1 images founded...
# This image traitment took 15.2753 seconds...
# --- PARCELLE 164408 ---
# collection
# 1 images founded...
# This image traitment took 17.0052 seconds...
# --- PARCELLE 164554 ---
# collection
# 1 images founded...
# This image traitment took 14.2056 seconds...
# --- PARCELLE 164558 ---
# collection
# 1 images founded...
# This image traitment took 14.624 seconds...
# --- PARCELLE 164562 ---
# collection
# 1 images founded...
# This image traitment took 12.745 seconds...
# --- PARCELLE 164570 ---
# collection
# 1 images founded...
# This image traitment took 15.2553 seconds...
# --- PARCELLE 164574 ---
# collection
# 1 images founded...
# This image traitment took 14.9372 seconds...
# --- PARCELLE 164693 ---
# collection
# 1 images founded...
# This image traitment took 14.6648 seconds...
# --- PARCELLE 164701 ---
# collection
# 1 images founded...
# This image traitment took 15.4309 seconds...
# --- PARCELLE 164705 ---
# collection
# 1 images founded...
# This image traitment took 15.851 seconds...
# --- PARCELLE 164709 ---
# collection
# 1 images founded...
# This image traitment took 15.0131 seconds...
# --- PARCELLE 164713 ---
# collection
# 1 images founded...
# This image traitment took 14.2112 seconds...
# --- PARCELLE 164818 ---
# collection
# 1 images founded...
# This image traitment took 14.9111 seconds...
# --- PARCELLE 164822 ---
# collection
# 1 images founded...
# This image traitment took 14.7018 seconds...
# --- PARCELLE 164826 ---
# collection
# 1 images founded...
# This image traitment took 14.6128 seconds...
# --- PARCELLE 164914 ---
# collection
# 1 images founded...
# This image traitment took 14.7916 seconds...
# --- PARCELLE 164918 ---
# collection
# 1 images founded...
# This image traitment took 12.9808 seconds...
# --- PARCELLE 164922 ---
# collection
# 1 images founded...
# This image traitment took 14.6425 seconds...
# --- PARCELLE 164999 ---
# collection
# 1 images founded...
# This image traitment took 12.939 seconds...
# --- PARCELLE 165003 ---
# collection
# 1 images founded...
# This image traitment took 10.6802 seconds...
# --- PARCELLE 165065 ---
# collection
# 1 images founded...
# This image traitment took 13.7166 seconds...
# Finish !...
# But we have a problem with this list of parcelles : []

# %% [markdown]
# Exportation of files :

# %%
data_used.shape
# Out:
# (2403, 5)

# %%
len(Stock_images_list)
# Out:
# 2403

# %% [markdown]
# Export in several json files

# %%
nb_parts = 10 # to define number of parts of the unique dict

# %%
Decoup_stock_images = []

len_sub_list = len(Stock_images_list)//nb_parts

for i in range(nb_parts-1):
    Decoup_stock_images.append(dict(list(Stock_images_list.items())[i*len_sub_list:(i+1)*len_sub_list]))
Decoup_stock_images.append(dict(list(Stock_images_list.items())[(nb_parts-1)*len_sub_list:]))

# %%
for i in range(nb_parts):
    print(f'... Exportation of dict n°{i} (lenght : {len(Decoup_stock_images[i])}) in a jsonfile...')
    list_json = json.dumps(Decoup_stock_images[i], cls=NumpyArrayEncoder)
    with open(f"Results_Images_Stock/Images_{Sattelite.split('/')[0].split('-')[0]}_{LFI}_part{i+1}.json", "w") as outfile:
        outfile.write(list_json)
    print(f'... Exportation dict n°{i} done...')
# Out:
# ... Exportation of dict n°0 (lenght : 240) in a jsonfile...
# ... Exportation dict n°0 done...
# ... Exportation of dict n°1 (lenght : 240) in a jsonfile...
# ... Exportation dict n°1 done...
# ... Exportation of dict n°2 (lenght : 240) in a jsonfile...
# ... Exportation dict n°2 done...
# ... Exportation of dict n°3 (lenght : 240) in a jsonfile...
# ... Exportation dict n°3 done...
# ... Exportation of dict n°4 (lenght : 240) in a jsonfile...
# ... Exportation dict n°4 done...
# ... Exportation of dict n°5 (lenght : 240) in a jsonfile...
# ... Exportation dict n°5 done...
# ... Exportation of dict n°6 (lenght : 240) in a jsonfile...
# ... Exportation dict n°6 done...
# ... Exportation of dict n°7 (lenght : 240) in a jsonfile...
# ... Exportation dict n°7 done...
# ... Exportation of dict n°8 (lenght : 240) in a jsonfile...
# ... Exportation dict n°8 done...
# ... Exportation of dict n°9 (lenght : 243) in a jsonfile...
# ... Exportation dict n°9 done...

# %% [markdown]
# Export in one unique json file

# %%
print('... Exportation in a jsonfile...')

list_json = json.dumps(Stock_images_list, cls=NumpyArrayEncoder)
with open(f"Results_Images_Stock/Images_{Sattelite.split('/')[0].split('-')[0]}_{LFI}.json", "w") as outfile:
    outfile.write(list_json)

print('... Exportation done...')

print('... Exportation of the problematic parcelle\'s list in a text...')

df_pb_list = pd.DataFrame(Problem_list, columns=['Problematic parcelles'])
df_pb_list.to_csv('Problematic_parcelles.csv')

print('...Exportation done...')
# Out:
# ... Exportation in a jsonfile...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 print('... Exportation in a jsonfile...')
# ----> 3 list_json = json.dumps(Stock_images_list, cls=NumpyArrayEncoder)
#       4 with open(f"Results_Images_Stock/Images_{Sattelite.split('/')[0].split('-')[0]}_{LFI}.json", "w") as outfile:
#       5     outfile.write(list_json)
#
# NameError: name 'json' is not defined

# %% [markdown]
# ---------------

# %% [markdown]
# Test ouverture de fichier :

# %%
with open(f"Results_Images_Stock/Images_{Sattelite.split('/')[0].split('-')[0]}_{LFI}.json", 'r') as openfile:
 
    json_object = json.load(openfile)

# %%
json_object['51'].get('DATE_INIT')
# Out:
# '2005-11-01 00:00:00'

# %%
json_object['51'].get('DATE_IMAGE_SAT')
# Out:
# '2005-06-30 00:00:00'

# %%
json_object['51'].get('LAT, LON')
# Out:
# [47.78162341651316, 8.612821767035694]

# %%
for _, funct in enumerate(json_object['51'].get('IMAGES_SAT')):
    plt.title(f'{funct}')
    plt.imshow(json_object['51'].get('IMAGES_SAT').get(funct), 'gray')
    plt.show()
